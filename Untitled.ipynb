# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\singh\Downloads\archive (2)\synthetic_ecommerce_order_risk_dataset.csv")
df.head(5)
# Out:
#           order_id  order_date      country device_type  traffic_source  \
# 0  ORD-2024-001936  2024-01-03      Belgium      Mobile        Paid Ads
# 1  ORD-2025-006495  2025-11-26  Netherlands     Desktop           Email
# 2  ORD-2023-001721  2023-11-07  Netherlands      Mobile  Organic Search
# 3  ORD-2024-009121  2024-05-28  Netherlands      Mobile  Organic Search
# 4  ORD-2025-000361  2025-01-31  Netherlands     Desktop          Direct
#
#   payment_method product_category  customer_age_days  previous_orders  \
# 0    Credit Card           Sports                381                3
# 1     Debit Card           Garden                561                6
# 2     Debit Card           Garden                324                2
# 3         Klarna      Electronics                378                3
# 4  Bank Transfer   Home & Kitchen                447                5
#
#    avg_order_value_eur  ...  shipping_distance_km  delivery_days_estimated  \
# ...

# %%
df.isnull().sum()
# Out:
# order_id                     0
# order_date                   0
# country                      0
# device_type                  0
# traffic_source               0
# payment_method               0
# product_category             0
# customer_age_days            0
# previous_orders              0
# avg_order_value_eur          0
# order_value_eur              0
# quantity                     0
# discount_rate                0
# shipping_distance_km         0
# delivery_days_estimated      0
# late_delivery_risk           0
# address_mismatch             0
# high_risk_ip                 0
# customer_support_contacts    0
# review_score                 0
# is_returned                  0
# is_fraud                     0
# risk_label                   0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.drop_duplicates()
# Out:
#               order_id  order_date      country device_type  traffic_source  \
# 0      ORD-2024-001936  2024-01-03      Belgium      Mobile        Paid Ads
# 1      ORD-2025-006495  2025-11-26  Netherlands     Desktop           Email
# 2      ORD-2023-001721  2023-11-07  Netherlands      Mobile  Organic Search
# 3      ORD-2024-009121  2024-05-28  Netherlands      Mobile  Organic Search
# 4      ORD-2025-000361  2025-01-31  Netherlands     Desktop          Direct
# ...                ...         ...          ...         ...             ...
# 11995  ORD-2023-011965  2023-02-19       France      Mobile    Social Media
# 11996  ORD-2023-005192  2023-05-12       France      Mobile  Organic Search
# 11997  ORD-2024-005391  2024-06-13      Germany      Mobile  Organic Search
# 11998  ORD-2025-000861  2025-04-04       Poland     Desktop     Marketplace
# 11999  ORD-2024-007271  2024-05-23  Netherlands     Desktop  Organic Search
#
# ...

# %%
df.head(3)
# Out:
#           order_id  order_date      country device_type  traffic_source  \
# 0  ORD-2024-001936  2024-01-03      Belgium      Mobile        Paid Ads
# 1  ORD-2025-006495  2025-11-26  Netherlands     Desktop           Email
# 2  ORD-2023-001721  2023-11-07  Netherlands      Mobile  Organic Search
#
#   payment_method product_category  customer_age_days  previous_orders  \
# 0    Credit Card           Sports                381                3
# 1     Debit Card           Garden                561                6
# 2     Debit Card           Garden                324                2
#
#    avg_order_value_eur  ...  shipping_distance_km  delivery_days_estimated  \
# 0                28.66  ...                 105.7                        5
# 1                41.93  ...                 528.2                        4
# 2               102.67  ...                 175.1                        5
#
#    late_delivery_risk  address_mismatch  high_risk_ip  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   order_id                   12000 non-null  str
#  1   order_date                 12000 non-null  str
#  2   country                    12000 non-null  str
#  3   device_type                12000 non-null  str
#  4   traffic_source             12000 non-null  str
#  5   payment_method             12000 non-null  str
#  6   product_category           12000 non-null  str
#  7   customer_age_days          12000 non-null  int64
#  8   previous_orders            12000 non-null  int64
#  9   avg_order_value_eur        12000 non-null  float64
#  10  order_value_eur            12000 non-null  float64
#  11  quantity                   12000 non-null  int64
#  12  discount_rate              12000 non-null  float64
#  13  shipping_distance_km       12000 non-null  float64
# ...

# %%
total_revenue = df['order_value_eur'].sum()

# %%
print(total_revenue)
# Out:
# 732640.0700000001

# %%
avgorder = df['avg_order_value_eur'].mean()
print(avgorder)
# Out:
# 48.94027750000001

# %%
country_sales = df.groupby('country')['order_value_eur'].sum()

# %%
print(country_sales)
# Out:
# country
# Belgium        121109.67
# France          80181.16
# Germany        102807.73
# Italy           54606.58
# Netherlands    205837.73
# Poland          51458.58
# Spain           63909.91
# Turkey          52728.71
# Name: order_value_eur, dtype: float64

# %%
froud_count = df['is_fraud'].sum()
print(froud_count)
# Out:
# 447

# %%
df.to_csv("cleaned_data.csv", index=False)

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\singh\\ev'
